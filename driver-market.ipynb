# %%
from market.Manager import Market
from utilities.utils import fullpath
import pandas as pd

# %%
dates = [20231231, 20240331,20240630,20240930,20241231,20250331]

for date in dates[-1:]:
    mkt = Market(date)
    mkt.get_caps();

# %%
mkt = Market(20250331)
mkt.get_daily_prices()
# Out:
# [*********************100%***********************]  40 of 40 completed
# Ticker          AC.PA  ACA.PA       AI.PA      AIR.PA      BN.PA     BNP.PA  \
# Date
# 2024-12-02  43.459999  12.560  159.539993  150.520004  64.839996  55.939999
# 2024-12-03  43.759998  12.510  160.020004  152.080002  64.800003  55.779999
# 2024-12-04  44.000000  12.635  161.160004  154.220001  64.739998  56.500000
# 2024-12-05  46.099998  12.925  161.660004  153.539993  64.980003  57.970001
# 2024-12-06  46.020000  13.035  162.059998  155.160004  64.860001  58.570000
# ...               ...     ...         ...         ...        ...        ...
# 2025-03-24  44.099998  16.850  177.339996  167.220001  70.699997  79.430000
# 2025-03-25  44.910000  17.295  178.720001  172.320007  71.059998  81.580002
# 2025-03-26  44.820000  17.135  176.740005  170.539993  70.540001  80.400002
# 2025-03-27  44.220001  17.090  176.440002  168.699997  70.820000  79.669998
# ...
